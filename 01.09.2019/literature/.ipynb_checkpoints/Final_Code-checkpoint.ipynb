# %%
from sklearn.metrics import silhouette_score

import pandas as pd
import numpy as np
from scipy.io import arff
from sklearn.mixture import GaussianMixture
import warnings
import glob
import cv2
import matplotlib.pyplot as plt
warnings.filterwarnings("ignore")
import skfuzzy as fuzz
import os
from copy import deepcopy
from sklearn import preprocessing

# %%
cwd=os.getcwd()
datasets=os.listdir(cwd+"\\literature\\")

# %%
thresh=0.2
limit=20

# %%
for j in datasets:
    DataSet=j
    if(j=='ALOI'):
        continue
    path=cwd+"\\literature\\"+DataSet+"\\"+DataSet+"_withoutdupl_norm.arff"
    #path_img= "C:\\Users\\soumy\\Desktop\\JU\Data for Outlier\\Data for Outlier\\001\\"
    data = arff.loadarff(path)
    
    print('Started for Dataset = '+j+'\n\n' )
    dict1={}
    dictoutlier={}
    dictfinal={}
    dictnotoutlier={}
    df12=pd.DataFrame(data[0])
    #df=df[df['class']=='C001']

    df_copy=deepcopy(df12)
    labelsss=df12['outlier']
    df12.drop(columns=['outlier','id'],inplace=True)


    x = df12.values #returns a numpy array
    min_max_scaler = preprocessing.MinMaxScaler()
    x_scaled = min_max_scaler.fit_transform(x)
    df12 = pd.DataFrame(x_scaled)
    pd.set_option('use_inf_as_na', True)
    columns=df12.columns
    df=df12
    for k in range(5):
        k=k+2
        silhouette=[]
        print('For K = '+str(k))
        print('\n\n\n')
        for i in range(limit):
            df.replace([np.inf, -np.inf], np.nan)
            df.dropna(inplace=True)
            df=df.reset_index()
            df.drop(columns='index',inplace=True)
            gmmkpp = GaussianMixture(n_components=k,random_state=100).fit(df)
            gmmkm = GaussianMixture(init_params='random',n_components=k,random_state=100).fit(df)
            cntr, u, u0, d, jm, p, fpc = fuzz.cluster.cmeans(df.T, k, 2, error=0.005, maxiter=1000, init=None)

            labelskmpp = gmmkpp.predict_proba(df)
            s1=silhouette_score(df, np.argmax(labelskmpp,axis=1))
            labelskm = gmmkm.predict_proba(df)
            
            # Silhouette Score
            s2=silhouette_score(df, np.argmax(labelskm,axis=1))
            s3=silhouette_score(df, np.argmax(u,axis=0))
            s1=abs(s1)
            s2=abs(s2)
            s3=abs(s3)
            print('Silhouette Score for KMEANS++ = '+str(s1))
            print('Silhouette Score for KMEANS = '+str(s2))
            print('Silhouette Score for CMEANS = '+str(s3))
            
            #Rand Index
            

            y_net = s1*labelskmpp + s2*labelskm + 2*s3*u.T

            #print(y_net)
            ################## SCORE ###############
            silhouette_avg = silhouette_score(df, np.argmax(y_net,axis=1))
            print('Average Weighted Silhouette Score =',silhouette_avg,'for i =',i+1)
            silhouette.append(silhouette_avg)
            ############### OUTLIER ########################
            if(i==0):
                outliers=np.where(np.max(y_net,axis=1) < thresh)
            else :
                thresh=thresh
                outliers=np.where(np.max(y_net,axis=1) < thresh)
            #if(len(outliers[0])==0):
                #print('All Outliers Removed.... Breaking')
                #break
            print(outliers[0])
            dict1.update({i:outliers[0]})
            mol=np.delete(y_net,outliers[0],axis=0)
            y_net=mol
            df=df.drop(outliers[0])
            df=df.reset_index()
            df.drop(columns='index',inplace=True)
            ylabel=np.argmax(y_net,axis=1)


            labels=pd.Series(ylabel,name="Labels")




            print(np.unique(labels,return_counts=True))
            df=df.join(labels)

            df.update(labels)

            dictoutlier.update({i:list(df[df['Labels']==np.unique(labels,return_counts=True)[1].argmin()].index)})
            dictnotoutlier.update({i:list(df[df['Labels']==np.unique(labels,return_counts=True)[1].argmax()].index)})

            centroids=df.groupby('Labels', as_index=False)[columns].mean()
            centroids=centroids.drop(columns='Labels')
            centroids=centroids.values.tolist()

            for i1 in range(k):
                    x=0
                    y=0
                    for j1 in range(len(columns)):
                        x+=np.sqrt(np.abs((df[columns[j1]] - centroids[i1][j1]) ** 2))
                    y=np.exp(-1*x)   
                    # sqrt((x1 - x2)^2 - (y1 - y2)^2)
                    df['distance_from_{}'.format(i1)] =x
                    df['Probability_of_{}'.format(i1)]=y



            for j2 in range(k):
                df1=df[df['Labels']==j2]
                for i2 in columns:
                    df1[i2]=np.abs(df[i2]-df1['Probability_of_{}'.format(j2)]/df1['distance_from_{}'.format(j2)])
                    #print(df1.head())
                    df.update(df1[i2])

            df=df[columns]

            #print(df.head(2))
            print('----------------------------------------------------------------------------------------')
            print()



        m=np.argmax(silhouette)

        #print('Best for m='+str(m+1)+' >=> '+ str(max(silhouette)))

        z=[]
        y1=[]
        for i in dictoutlier[m]:
            z.append(labelsss[i])

        foo=np.unique(z,return_counts=True)
        z=str(list(foo[0])+list(foo[1]))


        for i in dictnotoutlier[m]:
            y1.append(labelsss[i])

        foobar=np.unique(y1,return_counts=True)
        y1=str(list(foobar[0])+list(foobar[1]))


        fig=plt.figure()
        f=plt.plot(silhouette)
        plt.title(DataSet+' for  k = '+ str(k) )
        plt.xlabel("Iteration -----> \n MAX for "+str(m+1)+"\n OUTLIER:"+z+"\n NON-OUTLIER:"+y1)
        plt.ylabel("Average Silhouette Score")

        plt.savefig(cwd+'\\Results\\'+DataSet+' for k = '+str(k)+'.png',bbox_inches='tight')  
        plt.show()
        print('------------------------------------------------------------------------------------------------------')
        print('\n')
        print('\n')
# Out:
# Started for Dataset = Glass
#
#
# For K = 2
#
#
#
#
# Score for KMEANS++ = 0.5078825961940234
# Score for KMEANS = 0.440974455841558
# Score for CMEANS = 0.5983978596896012
# Average Weighted Silhouette Score = 0.5816026236159113 for i = 1
# []
# (array([0, 1], dtype=int64), array([165,  49], dtype=int64))
# ----------------------------------------------------------------------------------------
#
# Score for KMEANS++ = 0.4074442706828781
# Score for KMEANS = 0.356195206570849
# Score for CMEANS = 0.5942802322676277
# Average Weighted Silhouette Score = 0.589534704959945 for i = 2
# []
# (array([0, 1], dtype=int64), array([ 63, 151], dtype=int64))
# ----------------------------------------------------------------------------------------
#
# Score for KMEANS++ = 0.5075238795632429
# Score for KMEANS = 0.4187009728575396
# Score for CMEANS = 0.5996926327771072
# Average Weighted Silhouette Score = 0.5959064528748559 for i = 3
# []
# (array([0, 1], dtype=int64), array([ 70, 144], dtype=int64))
# ----------------------------------------------------------------------------------------
#
# Score for KMEANS++ = 0.5580431288527997
# Score for KMEANS = 0.48259226233099933
# Score for CMEANS = 0.6073374004214132
# Average Weighted Silhouette Score = 0.6093440800915053 for i = 4
# []
# (array([0, 1], dtype=int64), array([134,  80], dtype=int64))
# ----------------------------------------------------------------------------------------
#
# Score for KMEANS++ = 0.5882889760382493
# Score for KMEANS = 0.5942056029407801
# Score for CMEANS = 0.6202994425166143
# Average Weighted Silhouette Score = 0.6145905607628646 for i = 5
# []
# (array([0, 1], dtype=int64), array([ 84, 130], dtype=int64))
# ----------------------------------------------------------------------------------------
#
# Score for KMEANS++ = 0.6176170172608421
# Score for KMEANS = 0.6176170172608421
# Score for CMEANS = 0.6375323002757266
# Average Weighted Silhouette Score = 0.6375323002757266 for i = 6
# []
# (array([0, 1], dtype=int64), array([ 89, 125], dtype=int64))
# ----------------------------------------------------------------------------------------
#
# Score for KMEANS++ = 0.6239132867136138
# Score for KMEANS = 0.6264623281951688
# Score for CMEANS = 0.6484524433858397
# Average Weighted Silhouette Score = 0.6396432556685029 for i = 7
# []
# (array([0, 1], dtype=int64), array([ 92, 122], dtype=int64))
# ----------------------------------------------------------------------------------------
#
# Score for KMEANS++ = 0.626877430608144
# Score for KMEANS = 0.6296154857094549
# Score for CMEANS = 0.6505544596162156
# Average Weighted Silhouette Score = 0.6419088498325952 for i = 8
# []
# (array([0, 1], dtype=int64), array([ 92, 122], dtype=int64))
# ----------------------------------------------------------------------------------------
#
# Score for KMEANS++ = 0.46282288508824593
# Score for KMEANS = 0.5765619619363768
# Score for CMEANS = 0.6222767625035365
# Average Weighted Silhouette Score = 0.603930419424424 for i = 9
# []
# (array([0, 1], dtype=int64), array([ 95, 119], dtype=int64))
# ----------------------------------------------------------------------------------------
#
# Score for KMEANS++ = 0.45185626083179337
# Score for KMEANS = 0.577109476780742
# Score for CMEANS = 0.6193298485311903
# Average Weighted Silhouette Score = 0.563895240230803 for i = 10
# []
# (array([0, 1], dtype=int64), array([133,  81], dtype=int64))
# ----------------------------------------------------------------------------------------
#
# Score for KMEANS++ = 0.4609903150138943
# Score for KMEANS = 0.12078647939826398
# Score for CMEANS = 0.6278207151990916
# Average Weighted Silhouette Score = 0.5989266839358844 for i = 11
# []
# (array([0, 1], dtype=int64), array([ 86, 128], dtype=int64))
# ----------------------------------------------------------------------------------------
#
# Score for KMEANS++ = 0.4680213698972742
# Score for KMEANS = 0.14173077656401556
# Score for CMEANS = 0.6346100637502055
# Average Weighted Silhouette Score = 0.6134313984680418 for i = 12
# []
# (array([0, 1], dtype=int64), array([ 87, 127], dtype=int64))
# ----------------------------------------------------------------------------------------
#
# Score for KMEANS++ = 0.46148014854403896
# Score for KMEANS = 0.1499570178513752
# Score for CMEANS = 0.6366397466027114
# Average Weighted Silhouette Score = 0.6148923785346945 for i = 13
# []
# (array([0, 1], dtype=int64), array([ 87, 127], dtype=int64))
# ----------------------------------------------------------------------------------------
#
# Score for KMEANS++ = 0.4569417885019523
# Score for KMEANS = 0.36578665326663456
# Score for CMEANS = 0.6382231355493908
# Average Weighted Silhouette Score = 0.6186995896470826 for i = 14
# []
# (array([0, 1], dtype=int64), array([111, 103], dtype=int64))
# ----------------------------------------------------------------------------------------
#
# Score for KMEANS++ = 0.43757154678551696
# Score for KMEANS = 0.547848921046485
# Score for CMEANS = 0.6304076382928563
# Average Weighted Silhouette Score = 0.5862942387726551 for i = 15
# []
# (array([0, 1], dtype=int64), array([132,  82], dtype=int64))
# ----------------------------------------------------------------------------------------
#
# Score for KMEANS++ = 0.44370995064947005
# Score for KMEANS = 0.3461905824569151
# Score for CMEANS = 0.6358226114908064
# Average Weighted Silhouette Score = 0.5759882320507187 for i = 16
# []
# (array([0, 1], dtype=int64), array([ 88, 126], dtype=int64))
# ----------------------------------------------------------------------------------------
#
# Score for KMEANS++ = 0.45643565727825686
# Score for KMEANS = 0.1867491403523709
# Score for CMEANS = 0.6350318151622556
# Average Weighted Silhouette Score = 0.6129255315105833 for i = 17
# []
# (array([0, 1], dtype=int64), array([112, 102], dtype=int64))
# ----------------------------------------------------------------------------------------
#
# Score for KMEANS++ = 0.5733295764081346
# Score for KMEANS = 0.20919194753283588
# Score for CMEANS = 0.6338312544521492
# Average Weighted Silhouette Score = 0.558517972770056 for i = 18
# []
# (array([0, 1], dtype=int64), array([ 85, 129], dtype=int64))
# ----------------------------------------------------------------------------------------
#
# Score for KMEANS++ = 0.44989596386148056
# Score for KMEANS = 0.20874936515104744
# Score for CMEANS = 0.6379320750307632
# Average Weighted Silhouette Score = 0.5971320513852671 for i = 19
# []
# (array([0, 1], dtype=int64), array([ 91, 123], dtype=int64))
# ----------------------------------------------------------------------------------------
#
# Score for KMEANS++ = 0.587487758484572
# Score for KMEANS = 0.21696667583001786
# Score for CMEANS = 0.6437056223379818
# Average Weighted Silhouette Score = 0.5786222295474803 for i = 20
# []
# (array([0, 1], dtype=int64), array([ 90, 124], dtype=int64))
# ----------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------------------
#
#
#
#
# For K = 3
#
#
#
#
# Score for KMEANS++ = 0.7505555043876845
# Score for KMEANS = 0.3488142478453302
# Score for CMEANS = 0.7670206928265784
# Average Weighted Silhouette Score = 0.6894114521717857 for i = 1
# []
# (array([0, 1, 2], dtype=int64), array([ 11,  85, 118], dtype=int64))
# ----------------------------------------------------------------------------------------
#
# Score for KMEANS++ = 0.42754024010469416
# Score for KMEANS = 0.367542887758764
# Score for CMEANS = 0.7694864808773983
# Average Weighted Silhouette Score = 0.758915182396981 for i = 2
# []
# (array([0, 1, 2], dtype=int64), array([ 11, 107,  96], dtype=int64))
# ----------------------------------------------------------------------------------------
#
# Score for KMEANS++ = 0.13058702708566103
# Score for KMEANS = 0.03962032235599335
# Score for CMEANS = 0.49563577410442017
# Average Weighted Silhouette Score = 0.49529526090482806 for i = 3
# []
# (array([0, 1, 2], dtype=int64), array([ 61, 138,  15], dtype=int64))
# ----------------------------------------------------------------------------------------
#
# Score for KMEANS++ = 0.09549934930109034
# Score for KMEANS = 0.048231991229831725
# Score for CMEANS = 0.5714020936892292
# Average Weighted Silhouette Score = 0.5749166654052854 for i = 4
# []
# (array([0, 1, 2], dtype=int64), array([123,  74,  17], dtype=int64))
# ----------------------------------------------------------------------------------------
#
# Score for KMEANS++ = 0.036065673554595515
# Score for KMEANS = 0.1022471498576493
# Score for CMEANS = 0.6270148985300389
# Average Weighted Silhouette Score = 0.6270148985300389 for i = 5
# []
# (array([0, 1, 2], dtype=int64), array([ 97,  17, 100], dtype=int64))
# ----------------------------------------------------------------------------------------
#
# Score for KMEANS++ = 0.028833989125958956
# Score for KMEANS = 0.033710750042872065
# Score for CMEANS = 0.4668268667516476
# Average Weighted Silhouette Score = 0.47485200654247467 for i = 6
# []
# (array([0, 1, 2], dtype=int64), array([ 19,  88, 107], dtype=int64))
# ----------------------------------------------------------------------------------------
#
# Score for KMEANS++ = 0.12412940144286037
# Score for KMEANS = 0.1960566583539459
# Score for CMEANS = 0.8525836222276179
# Average Weighted Silhouette Score = 0.8525836222276179 for i = 7
# []
# (array([0, 1, 2], dtype=int64), array([  3, 191,  20], dtype=int64))
# ----------------------------------------------------------------------------------------
#
# Score for KMEANS++ = 0.13545967846647683
# Score for KMEANS = 0.07128810514575855
# Score for CMEANS = 0.8405684230901804
# Average Weighted Silhouette Score = 0.8405684230901804 for i = 8
# []
# (array([0, 1, 2], dtype=int64), array([ 22, 189,   3], dtype=int64))
# ----------------------------------------------------------------------------------------
#
# Score for KMEANS++ = 0.16628575321163788
# Score for KMEANS = 0.09968630785320931
# Score for CMEANS = 0.8126420987822607
# Average Weighted Silhouette Score = 0.8126420987822607 for i = 9
# []
# (array([0, 1, 2], dtype=int64), array([ 32,   3, 179], dtype=int64))
# ----------------------------------------------------------------------------------------
#
# Score for KMEANS++ = 0.18375705451616517
# Score for KMEANS = 0.1480070710793213
# Score for CMEANS = 0.8039711118937276
# Average Weighted Silhouette Score = 0.8052067867728493 for i = 10
# []
# (array([0, 1, 2], dtype=int64), array([  3,  34, 177], dtype=int64))
# ----------------------------------------------------------------------------------------
#
# Score for KMEANS++ = 0.18189474884806742
# Score for KMEANS = 0.03535523703187085
# Score for CMEANS = 0.7916548089369218
# Average Weighted Silhouette Score = 0.7916548089369218 for i = 11
# []
# (array([0, 1, 2], dtype=int64), array([ 36, 174,   4], dtype=int64))
# ----------------------------------------------------------------------------------------
#
# Score for KMEANS++ = 0.16792876209181
# Score for KMEANS = 0.12464933969004523
# Score for CMEANS = 0.7782839998248112
# Average Weighted Silhouette Score = 0.7782839998248112 for i = 12
# []
# (array([0, 1, 2], dtype=int64), array([170,  39,   5], dtype=int64))
# ----------------------------------------------------------------------------------------
#
# Score for KMEANS++ = 0.18766287560546085
# Score for KMEANS = 0.1378378960606619
# Score for CMEANS = 0.7763008479744853
# Average Weighted Silhouette Score = 0.7743395355153745 for i = 13
# []
# (array([0, 1, 2], dtype=int64), array([ 36,   5, 173], dtype=int64))
# ----------------------------------------------------------------------------------------
#
# Score for KMEANS++ = 0.12977847115792063
# Score for KMEANS = 0.09322343819954965
# Score for CMEANS = 0.7808675142892093
# Average Weighted Silhouette Score = 0.7808675142892093 for i = 14
# []
# (array([0, 1, 2], dtype=int64), array([  5, 169,  40], dtype=int64))
# ----------------------------------------------------------------------------------------
#
# Score for KMEANS++ = 0.12365096292302377
# Score for KMEANS = 0.05831857611457082
# Score for CMEANS = 0.7797672517929141
# Average Weighted Silhouette Score = 0.7804895177133506 for i = 15
# []
# (array([0, 1, 2], dtype=int64), array([ 38,   5, 171], dtype=int64))
# ----------------------------------------------------------------------------------------
#
# Score for KMEANS++ = 0.11272720415248641
# Score for KMEANS = 0.11120569575141773
# Score for CMEANS = 0.7604983365525763
# Average Weighted Silhouette Score = 0.7604983365525763 for i = 16
# []
# (array([0, 1, 2], dtype=int64), array([169,  40,   5], dtype=int64))
# ----------------------------------------------------------------------------------------
#
# Score for KMEANS++ = 0.12544949306433073
# Score for KMEANS = 0.1192521072025483
# Score for CMEANS = 0.7605354782427305
# Average Weighted Silhouette Score = 0.7560922752679052 for i = 17
# []
# (array([0, 1, 2], dtype=int64), array([  5, 167,  42], dtype=int64))
# ----------------------------------------------------------------------------------------
#
# Score for KMEANS++ = 0.13453294194194002
# Score for KMEANS = 0.11530475923019211
# Score for CMEANS = 0.7577059471460872
# Average Weighted Silhouette Score = 0.7534669597383553 for i = 18
# []
# (array([0, 1, 2], dtype=int64), array([  5, 167,  42], dtype=int64))
# ----------------------------------------------------------------------------------------
#
# Score for KMEANS++ = 0.13830796091825723
# Score for KMEANS = 0.12373592105149765
# Score for CMEANS = 0.759322625478465
# Average Weighted Silhouette Score = 0.7551591952138691 for i = 19
# []
# (array([0, 1, 2], dtype=int64), array([  5, 167,  42], dtype=int64))
# ----------------------------------------------------------------------------------------
#
# Score for KMEANS++ = 0.13392127761011705
# Score for KMEANS = 0.1194324287141796
# Score for CMEANS = 0.7589170121316743
# Average Weighted Silhouette Score = 0.7526854963388782 for i = 20
# []
# (array([0, 1, 2], dtype=int64), array([166,   5,  43], dtype=int64))
# ----------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------------------
#
#
#
#
# For K = 4
#
#
#
#
# Score for KMEANS++ = 0.6509943811131664
# Score for KMEANS = 0.41616264309953205
# Score for CMEANS = 0.7596705678879266
# Average Weighted Silhouette Score = 0.7416374518569286 for i = 1
# []
# (array([0, 1, 2, 3], dtype=int64), array([149,   5,  43,  17], dtype=int64))
# ----------------------------------------------------------------------------------------
#
# Score for KMEANS++ = 0.18869778913777155
# Score for KMEANS = 0.3886366298933783
# Score for CMEANS = 0.7735261921711571
# Average Weighted Silhouette Score = 0.7635614068732557 for i = 2
# []
# (array([0, 1, 2, 3], dtype=int64), array([ 26, 169,  14,   5], dtype=int64))
# ----------------------------------------------------------------------------------------
#
# Score for KMEANS++ = 0.42386732364128327
# Score for KMEANS = 0.13713106768706068
# Score for CMEANS = 0.7644185606895503
# Average Weighted Silhouette Score = 0.7622492114885336 for i = 3
# []
# (array([0, 1, 2, 3], dtype=int64), array([ 15,  53, 140,   6], dtype=int64))
# ----------------------------------------------------------------------------------------
#
# Score for KMEANS++ = 0.7097275863380319
# Score for KMEANS = 0.27092686775130537
# Score for CMEANS = 0.6624626406222499
# Average Weighted Silhouette Score = 0.6575461880168914 for i = 4
# []
# (array([0, 1, 2, 3], dtype=int64), array([  7,  20, 170,  17], dtype=int64))
# ----------------------------------------------------------------------------------------
#
# Score for KMEANS++ = 0.11927183351501346
# Score for KMEANS = 0.4296890443209553
# Score for CMEANS = 0.780618350443242
# Average Weighted Silhouette Score = 0.780618350443242 for i = 5
# []
# (array([0, 1, 2, 3], dtype=int64), array([  1, 180,   7,  26], dtype=int64))
# ----------------------------------------------------------------------------------------
#
# Score for KMEANS++ = 0.07297632723130515
# Score for KMEANS = 0.4789429310597893
# Score for CMEANS = 0.7678259570245549
# Average Weighted Silhouette Score = 0.7718797763811659 for i = 6
# []
# (array([0, 1, 2, 3], dtype=int64), array([  1,   7, 177,  29], dtype=int64))
# ----------------------------------------------------------------------------------------
#
# Score for KMEANS++ = 0.05113587093739953
# Score for KMEANS = 0.49487726381917324
# Score for CMEANS = 0.7484183110042351
# Average Weighted Silhouette Score = 0.7423553633658139 for i = 7
# []
# (array([0, 1, 2, 3], dtype=int64), array([  1,  28, 174,  11], dtype=int64))
# ----------------------------------------------------------------------------------------
#
# Score for KMEANS++ = 0.04967161223057026
# Score for KMEANS = 0.503590592517595
# Score for CMEANS = 0.7237177056434574
# Average Weighted Silhouette Score = 0.7344904685183092 for i = 8
# []
# (array([0, 1, 2, 3], dtype=int64), array([173,  28,  12,   1], dtype=int64))
# ----------------------------------------------------------------------------------------
#
# Score for KMEANS++ = 0.04161859707857265
# Score for KMEANS = 0.5016693585320341
# Score for CMEANS = 0.6938931691904194
# Average Weighted Silhouette Score = 0.6864989376340562 for i = 9
# []
# (array([0, 1, 2, 3], dtype=int64), array([162,  36,   1,  15], dtype=int64))
# ----------------------------------------------------------------------------------------
#
# Score for KMEANS++ = 0.16888069945761608
# Score for KMEANS = 0.4977920018842438
# Score for CMEANS = 0.6979650967187618
# Average Weighted Silhouette Score = 0.6967446685430617 for i = 10
# []
# (array([0, 1, 2, 3], dtype=int64), array([ 52,   1, 146,  15], dtype=int64))
# ----------------------------------------------------------------------------------------
#
# Score for KMEANS++ = 0.29987535820787165
# Score for KMEANS = 0.1122672556746679
# Score for CMEANS = 0.7281372953647388
# Average Weighted Silhouette Score = 0.7249282988588073 for i = 11
# []
# (array([0, 1, 2, 3], dtype=int64), array([135,   1,  62,  16], dtype=int64))
# ----------------------------------------------------------------------------------------
#
# Score for KMEANS++ = 0.005283014492203507
# Score for KMEANS = 0.11189417066872631
# Score for CMEANS = 0.6317522523608133
# Average Weighted Silhouette Score = 0.6304163763151373 for i = 12
# []
# (array([0, 1, 2, 3], dtype=int64), array([152,  39,   2,  21], dtype=int64))
# ----------------------------------------------------------------------------------------
#
# Score for KMEANS++ = 0.012170518236845448
# Score for KMEANS = 0.1036252571487051
# Score for CMEANS = 0.8000691815344004
# Average Weighted Silhouette Score = 0.8000691815344004 for i = 13
# []
# (array([0, 1, 2, 3], dtype=int64), array([187,   1,  23,   3], dtype=int64))
# ----------------------------------------------------------------------------------------
#
# Score for KMEANS++ = 0.0031164875007533423
# Score for KMEANS = 0.07873651266723188
# Score for CMEANS = 0.7860817278892005
# Average Weighted Silhouette Score = 0.7860817278892005 for i = 14
# []
# (array([0, 1, 2, 3], dtype=int64), array([184,   3,  26,   1], dtype=int64))
# ----------------------------------------------------------------------------------------
#
# Score for KMEANS++ = 0.009043759466771798
# Score for KMEANS = 0.08305120028069617
# Score for CMEANS = 0.716202305714107
# Average Weighted Silhouette Score = 0.7165108082990859 for i = 15
# []
# (array([0, 1, 2, 3], dtype=int64), array([  7,   1,  32, 174], dtype=int64))
# ----------------------------------------------------------------------------------------
#
# Score for KMEANS++ = 0.012407450318174999
# Score for KMEANS = 0.06620693146934538
# Score for CMEANS = 0.721755609396894
# Average Weighted Silhouette Score = 0.7195571359121175 for i = 16
# []
# (array([0, 1, 2, 3], dtype=int64), array([  1,  37,   7, 169], dtype=int64))
# ----------------------------------------------------------------------------------------
#
# Score for KMEANS++ = 0.015266986084575879
# Score for KMEANS = 0.0549299873283432
# Score for CMEANS = 0.7242884362573374
# Average Weighted Silhouette Score = 0.7306534737030648 for i = 17
# []
# (array([0, 1, 2, 3], dtype=int64), array([ 39,   6, 167,   2], dtype=int64))
# ----------------------------------------------------------------------------------------
#
# Score for KMEANS++ = 0.017046941057628422
# Score for KMEANS = 0.05046688066699772
# Score for CMEANS = 0.732429045684727
# Average Weighted Silhouette Score = 0.734157525072151 for i = 18
# []
# (array([0, 1, 2, 3], dtype=int64), array([  2, 165,   6,  41], dtype=int64))
# ----------------------------------------------------------------------------------------
#
# Score for KMEANS++ = 0.018420799686639136
# Score for KMEANS = 0.04906185025340262
# Score for CMEANS = 0.7351484727629307
# Average Weighted Silhouette Score = 0.7351484727629307 for i = 19
# []
# (array([0, 1, 2, 3], dtype=int64), array([  2,  40,   7, 165], dtype=int64))
# ----------------------------------------------------------------------------------------
#
# Score for KMEANS++ = 0.01833042337410576
# Score for KMEANS = 0.04163781780992159
# Score for CMEANS = 0.7352369784704328
# Average Weighted Silhouette Score = 0.7352369784704328 for i = 20
# []
# (array([0, 1, 2, 3], dtype=int64), array([ 40, 165,   7,   2], dtype=int64))
# ----------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------------------
#
#
#
#
# For K = 5
#
#
#
#
# Score for KMEANS++ = 0.145508848195945
# Score for KMEANS = 0.020864089526114626
# Score for CMEANS = 0.7164038196612098
# Average Weighted Silhouette Score = 0.7140422094423091 for i = 1
# []
# (array([0, 1, 2, 3, 4], dtype=int64), array([130,  61,  19,   1,   3], dtype=int64))
# ----------------------------------------------------------------------------------------
#
# Score for KMEANS++ = 0.2606303540396941
# Score for KMEANS = 0.06713298719064334
# Score for CMEANS = 0.6355520815145724
# Average Weighted Silhouette Score = 0.6381611417142635 for i = 2
# []
# (array([0, 1, 2, 3, 4], dtype=int64), array([  1, 121,  70,   3,  19], dtype=int64))
# ----------------------------------------------------------------------------------------
#
# Score for KMEANS++ = 0.2108006830000436
# Score for KMEANS = 0.08264648158200452
# Score for CMEANS = 0.6390503468887104
# Average Weighted Silhouette Score = 0.6338773925277493 for i = 3
# []
# (array([0, 1, 2, 3, 4], dtype=int64), array([110,   3,  21,   1,  79], dtype=int64))
# ----------------------------------------------------------------------------------------
#
# Score for KMEANS++ = 0.26939946247006313
# Score for KMEANS = 0.07916257194754357
# Score for CMEANS = 0.6334535312824995
# Average Weighted Silhouette Score = 0.6291734607666578 for i = 4
# []
# (array([0, 1, 2, 3, 4], dtype=int64), array([  3,  20,  79,   1, 111], dtype=int64))
# ----------------------------------------------------------------------------------------
#
# Score for KMEANS++ = 0.2548840232376282
# Score for KMEANS = 0.07362990384405131
# Score for CMEANS = 0.6358948989180958
# Average Weighted Silhouette Score = 0.6375019132579954 for i = 5
# []
# (array([0, 1, 2, 3, 4], dtype=int64), array([  1,   3,  21, 106,  83], dtype=int64))
# ----------------------------------------------------------------------------------------
#
# Score for KMEANS++ = 0.2695639806547472
# Score for KMEANS = 0.10226696058782137
# Score for CMEANS = 0.6335771230929909
# Average Weighted Silhouette Score = 0.6287751891286931 for i = 6
# []
# (array([0, 1, 2, 3, 4], dtype=int64), array([  1,   3, 112,  77,  21], dtype=int64))
# ----------------------------------------------------------------------------------------
#
# Score for KMEANS++ = 0.2629705733667125
# Score for KMEANS = 0.197437875535451
# Score for CMEANS = 0.6390335614699822
# Average Weighted Silhouette Score = 0.6393894661942677 for i = 7
# []
# (array([0, 1, 2, 3, 4], dtype=int64), array([ 21,   2, 105,   2,  84], dtype=int64))
# ----------------------------------------------------------------------------------------
#
# Score for KMEANS++ = 0.24925537021180472
# Score for KMEANS = 0.18672896141030831
# Score for CMEANS = 0.6350840874318517
# Average Weighted Silhouette Score = 0.6359323252370649 for i = 8
# []
# (array([0, 1, 2, 3, 4], dtype=int64), array([ 81,   2, 108,   2,  21], dtype=int64))
# ----------------------------------------------------------------------------------------
#
# Score for KMEANS++ = 0.2641701406323774
# Score for KMEANS = 0.11049669441815545
# Score for CMEANS = 0.6432738649017413
# Average Weighted Silhouette Score = 0.6467933283009769 for i = 9
# []
# (array([0, 1, 2, 3, 4], dtype=int64), array([ 88,   3, 101,  21,   1], dtype=int64))
# ----------------------------------------------------------------------------------------
#
# Score for KMEANS++ = 0.23044079053743602
# Score for KMEANS = 0.09466580703442765
# Score for CMEANS = 0.6808850052671934
# Average Weighted Silhouette Score = 0.6834668429959947 for i = 10
# []
# (array([0, 1, 2, 3, 4], dtype=int64), array([159,  19,  32,   1,   3], dtype=int64))
# ----------------------------------------------------------------------------------------
#
# Score for KMEANS++ = 0.2651987757334347
# Score for KMEANS = 0.14099787831938052
# Score for CMEANS = 0.6169685428230515
# Average Weighted Silhouette Score = 0.6219221907767554 for i = 11
# []
# (array([0, 1, 2, 3, 4], dtype=int64), array([  3,  21,  41, 148,   1], dtype=int64))
# ----------------------------------------------------------------------------------------
#
# Score for KMEANS++ = 0.2089953537141491
# Score for KMEANS = 0.1135528631039749
# Score for CMEANS = 0.6599433947009998
# Average Weighted Silhouette Score = 0.6579795656303168 for i = 12
# []
# (array([0, 1, 2, 3, 4], dtype=int64), array([108,  22,  80,   1,   3], dtype=int64))
# ----------------------------------------------------------------------------------------
#
# Score for KMEANS++ = 0.27381796744718717
# Score for KMEANS = 0.1434681221232519
# Score for CMEANS = 0.652453253557963
# Average Weighted Silhouette Score = 0.6538845764302613 for i = 13
# []
# (array([0, 1, 2, 3, 4], dtype=int64), array([100,   2,  33,   2,  77], dtype=int64))
# ----------------------------------------------------------------------------------------
#
# Score for KMEANS++ = 0.2475394564516331
# Score for KMEANS = 0.14069273306277613
# Score for CMEANS = 0.6740007957950578
# Average Weighted Silhouette Score = 0.664835689293261 for i = 14
# []
# (array([0, 1, 2, 3, 4], dtype=int64), array([97,  7, 31,  1, 78], dtype=int64))
# ----------------------------------------------------------------------------------------
#
# Score for KMEANS++ = 0.1606396505458903
# Score for KMEANS = 0.05291454464823837
# Score for CMEANS = 0.6661373490925878
# Average Weighted Silhouette Score = 0.6616811121243912 for i = 15
# []
# (array([0, 1, 2, 3, 4], dtype=int64), array([ 10,   6, 148,  45,   5], dtype=int64))
# ----------------------------------------------------------------------------------------
#
# Score for KMEANS++ = 0.0014699900712011114
# Score for KMEANS = 0.074633721950378
# Score for CMEANS = 0.6460724505807305
# Average Weighted Silhouette Score = 0.6460724505807305 for i = 16
# []
# (array([0, 1, 2, 3, 4], dtype=int64), array([  6, 138,  22,  42,   6], dtype=int64))
# ----------------------------------------------------------------------------------------
#
# Score for KMEANS++ = 0.0013533495787569278
# Score for KMEANS = 0.0666387254218904
# Score for CMEANS = 0.6367368650740433
# Average Weighted Silhouette Score = 0.6367368650740433 for i = 17
# []
# (array([0, 1, 2, 3, 4], dtype=int64), array([  7,   6,  41,  22, 138], dtype=int64))
# ----------------------------------------------------------------------------------------
#
# Score for KMEANS++ = 0.001069896865237802
# Score for KMEANS = 0.07478321948509593
# Score for CMEANS = 0.6310388840139759
# Average Weighted Silhouette Score = 0.6310388840139759 for i = 18
# []
# (array([0, 1, 2, 3, 4], dtype=int64), array([ 23, 136,   6,  40,   9], dtype=int64))
# ----------------------------------------------------------------------------------------
#
# Score for KMEANS++ = 0.0015330956268409409
# Score for KMEANS = 0.03898782270318543
# Score for CMEANS = 0.623581359909377
# Average Weighted Silhouette Score = 0.6139934822742742 for i = 19
# []
# (array([0, 1, 2, 3, 4], dtype=int64), array([94, 24,  6, 10, 80], dtype=int64))
# ----------------------------------------------------------------------------------------
#
# Score for KMEANS++ = 0.2500805755558506
# Score for KMEANS = 0.21091432561957607
# Score for CMEANS = 0.6323409186919933
# Average Weighted Silhouette Score = 0.6195723672777373 for i = 20
# []
# (array([0, 1, 2, 3, 4], dtype=int64), array([  7,  38,  26,   9, 134], dtype=int64))
# ----------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------------------
#
#
#
#
# For K = 6
#
#
#
#
# Score for KMEANS++ = 0.25676993045813923
# Score for KMEANS = 0.2953036616020068
# Score for CMEANS = 0.6211512792855884
# Average Weighted Silhouette Score = 0.6151207482573456 for i = 1
# []
# (array([0, 1, 2, 3, 4, 5], dtype=int64), array([34,  5,  9, 69, 92,  5], dtype=int64))
# ----------------------------------------------------------------------------------------
#
# Score for KMEANS++ = 0.0017957417827252256
# Score for KMEANS = 0.3635782550593013
# Score for CMEANS = 0.6159163737055007
# Average Weighted Silhouette Score = 0.6159163737055007 for i = 2
# []
# (array([0, 1, 2, 3, 4, 5], dtype=int64), array([ 7, 34,  4, 61, 10, 98], dtype=int64))
# ----------------------------------------------------------------------------------------
#
# Score for KMEANS++ = 0.0075390330567395684
# Score for KMEANS = 0.24165878188767634
# Score for CMEANS = 0.6283022433050063
# Average Weighted Silhouette Score = 0.6283022433050063 for i = 3
# []
# (array([0, 1, 2, 3, 4, 5], dtype=int64), array([ 13, 122,   3,  26,  10,  40], dtype=int64))
# ----------------------------------------------------------------------------------------
#
# Score for KMEANS++ = 0.0455095206078219
# Score for KMEANS = 0.24479374489468034
# Score for CMEANS = 0.5929571503124869
# Average Weighted Silhouette Score = 0.5849262567983524 for i = 4
# []
# (array([0, 1, 2, 3, 4, 5], dtype=int64), array([  5,  32,  42,   8,  13, 114], dtype=int64))
# ----------------------------------------------------------------------------------------
#
# Score for KMEANS++ = 0.024087807869788445
# Score for KMEANS = 0.2480145773285822
# Score for CMEANS = 0.6390057774359895
# Average Weighted Silhouette Score = 0.6335724165031 for i = 5
# []
# (array([0, 1, 2, 3, 4, 5], dtype=int64), array([ 15,   2,  47,  13,  34, 103], dtype=int64))
# ----------------------------------------------------------------------------------------
#
# Score for KMEANS++ = 0.012839274171529835
# Score for KMEANS = 0.2511167324439624
# Score for CMEANS = 0.6494146165157045
# Average Weighted Silhouette Score = 0.648357320688114 for i = 6
# []
# (array([0, 1, 2, 3, 4, 5], dtype=int64), array([ 12,  59, 117,   2,  18,   6], dtype=int64))
# ----------------------------------------------------------------------------------------
#
# Score for KMEANS++ = 0.006865071149247425
# Score for KMEANS = 0.2500439367927319
# Score for CMEANS = 0.6448556973884397
# Average Weighted Silhouette Score = 0.6431090430270004 for i = 7
# []
# (array([0, 1, 2, 3, 4, 5], dtype=int64), array([  7, 116,  12,  18,   2,  59], dtype=int64))
# ----------------------------------------------------------------------------------------
#
# Score for KMEANS++ = 0.2241895435455364
# Score for KMEANS = 0.2542462144974586
# Score for CMEANS = 0.640649654915234
# Average Weighted Silhouette Score = 0.6387439322643086 for i = 8
# []
# (array([0, 1, 2, 3, 4, 5], dtype=int64), array([ 59, 115,   2,  19,  12,   7], dtype=int64))
# ----------------------------------------------------------------------------------------
#
# Score for KMEANS++ = 0.00973187434982664
# Score for KMEANS = 0.25484226936105886
# Score for CMEANS = 0.6370088827801874
# Average Weighted Silhouette Score = 0.6350761205299116 for i = 9
# []
# (array([0, 1, 2, 3, 4, 5], dtype=int64), array([ 21,   7,  59, 113,  12,   2], dtype=int64))
# ----------------------------------------------------------------------------------------
#
# Score for KMEANS++ = 0.014481917231347253
# Score for KMEANS = 0.2548093689678569
# Score for CMEANS = 0.6321809141771367
# Average Weighted Silhouette Score = 0.6321809141771367 for i = 10
# []
# (array([0, 1, 2, 3, 4, 5], dtype=int64), array([  2,  20,  12, 113,  59,   8], dtype=int64))
# ----------------------------------------------------------------------------------------
#
# Score for KMEANS++ = 0.017880788754322644
# Score for KMEANS = 0.25799114568835274
# Score for CMEANS = 0.624061639341824
# Average Weighted Silhouette Score = 0.6260809366407473 for i = 11
# []
# (array([0, 1, 2, 3, 4, 5], dtype=int64), array([  2, 112,   8,  60,  12,  20], dtype=int64))
# ----------------------------------------------------------------------------------------
#
# Score for KMEANS++ = 0.022472931407213115
# Score for KMEANS = 0.2540976398844149
# Score for CMEANS = 0.617746867754204
# Average Weighted Silhouette Score = 0.615280492309146 for i = 12
# []
# (array([0, 1, 2, 3, 4, 5], dtype=int64), array([ 47,   4,  11, 109,  29,  14], dtype=int64))
# ----------------------------------------------------------------------------------------
#
# Score for KMEANS++ = 0.10085819253895645
# Score for KMEANS = 0.24762341667765392
# Score for CMEANS = 0.6326914422023616
# Average Weighted Silhouette Score = 0.6326914422023616 for i = 13
# []
# (array([0, 1, 2, 3, 4, 5], dtype=int64), array([12, 13, 96,  2, 54, 37], dtype=int64))
# ----------------------------------------------------------------------------------------
#
# Score for KMEANS++ = 0.01940436133736262
# Score for KMEANS = 0.32074792335964425
# Score for CMEANS = 0.65764373748231
# Average Weighted Silhouette Score = 0.6537962941179589 for i = 14
# []
# (array([0, 1, 2, 3, 4, 5], dtype=int64), array([101,  13,  37,  10,   6,  47], dtype=int64))
# ----------------------------------------------------------------------------------------
#
# Score for KMEANS++ = 0.011895219170077648
# Score for KMEANS = 0.3045651210185547
# Score for CMEANS = 0.6339580413538999
# Average Weighted Silhouette Score = 0.6374090894141421 for i = 15
# []
# (array([0, 1, 2, 3, 4, 5], dtype=int64), array([13, 99, 10,  6, 38, 48], dtype=int64))
# ----------------------------------------------------------------------------------------
#
# Score for KMEANS++ = 0.013442115817063977
# Score for KMEANS = 0.3596441935570935
# Score for CMEANS = 0.7090628516299522
# Average Weighted Silhouette Score = 0.6953699210586171 for i = 16
# []
# (array([0, 1, 2, 3, 4, 5], dtype=int64), array([ 40,  12,   5, 144,   2,  11], dtype=int64))
# ----------------------------------------------------------------------------------------
#
# Score for KMEANS++ = 0.004102019578061638
# Score for KMEANS = 0.21874336955744192
# Score for CMEANS = 0.6561576744988761
# Average Weighted Silhouette Score = 0.6561576744988761 for i = 17
# []
# (array([0, 1, 2, 3, 4, 5], dtype=int64), array([ 6, 11, 54, 13, 89, 41], dtype=int64))
# ----------------------------------------------------------------------------------------
#
# Score for KMEANS++ = 0.008082583494074355
# Score for KMEANS = 0.2277514016709464
# Score for CMEANS = 0.6702677440902872
# Average Weighted Silhouette Score = 0.6458910358817528 for i = 18
# []
# (array([0, 1, 2, 3, 4, 5], dtype=int64), array([ 41,   6, 131,  12,  13,  11], dtype=int64))
# ----------------------------------------------------------------------------------------
#
# Score for KMEANS++ = 0.009261198606697002
# Score for KMEANS = 0.30665703561524865
# Score for CMEANS = 0.640387511894367
# Average Weighted Silhouette Score = 0.640387511894367 for i = 19
# []
# (array([0, 1, 2, 3, 4, 5], dtype=int64), array([ 6, 55, 13, 87, 42, 11], dtype=int64))
# ----------------------------------------------------------------------------------------
#
# Score for KMEANS++ = 0.03517278231731389
# Score for KMEANS = 0.29167128670756204
# Score for CMEANS = 0.6263293640314636
# Average Weighted Silhouette Score = 0.6238502097213681 for i = 20
# []
# (array([0, 1, 2, 3, 4, 5], dtype=int64), array([61, 13, 80, 42,  6, 12], dtype=int64))
# ----------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------------------
#
#
#
#
# Started for Dataset = Ionosphere
#
#
# For K = 2
#
#
#
#
# Score for KMEANS++ = 0.17724787960709304
# Score for KMEANS = 0.1232921480105909
# Score for CMEANS = 0.29692769711190276
# Average Weighted Silhouette Score = 0.20191202815040535 for i = 1
# []
# (array([0, 1], dtype=int64), array([186, 165], dtype=int64))
# ----------------------------------------------------------------------------------------
#
# Score for KMEANS++ = 0.17087691126886745
# Score for KMEANS = 0.1053302136419444
# Score for CMEANS = 0.25394295487595414
# Average Weighted Silhouette Score = 0.18044198624010788 for i = 2
# []
# (array([0, 1], dtype=int64), array([192, 159], dtype=int64))
# ----------------------------------------------------------------------------------------
#
# Score for KMEANS++ = 0.16047114414469765
# Score for KMEANS = 0.11122435247667971
# Score for CMEANS = 0.24630134726562877
# Average Weighted Silhouette Score = 0.06467588864047821 for i = 3
# []
# (array([0, 1], dtype=int64), array([148, 203], dtype=int64))
# ----------------------------------------------------------------------------------------
#
# Score for KMEANS++ = 0.15697513480935607
# Score for KMEANS = 0.10999321139539106
# Score for CMEANS = 0.2417423551652001
# Average Weighted Silhouette Score = 0.16109648096317944 for i = 4
# []
# (array([0, 1], dtype=int64), array([190, 161], dtype=int64))
# ----------------------------------------------------------------------------------------
#
# Score for KMEANS++ = 0.13385889834147258
# Score for KMEANS = 0.10982930760492254
# Score for CMEANS = 0.23717292859722544
# Average Weighted Silhouette Score = 0.14005711326337414 for i = 5
# []
# (array([0, 1], dtype=int64), array([184, 167], dtype=int64))
# ----------------------------------------------------------------------------------------
#
# Score for KMEANS++ = 0.13272243037829215
# Score for KMEANS = 0.11006920552309216
# Score for CMEANS = 0.2331643144873851
# Average Weighted Silhouette Score = 0.05866040607890685 for i = 6
# []
# (array([0, 1], dtype=int64), array([164, 187], dtype=int64))
# ----------------------------------------------------------------------------------------
#
# Score for KMEANS++ = 0.130983535232562
# Score for KMEANS = 0.10913869660575319
# Score for CMEANS = 0.22592590682166813
# Average Weighted Silhouette Score = 0.12785931800337555 for i = 7
# []
# (array([0, 1], dtype=int64), array([188, 163], dtype=int64))
# ----------------------------------------------------------------------------------------
#
# Score for KMEANS++ = 0.13007887251427286
# Score for KMEANS = 0.10925231677592462
# Score for CMEANS = 0.22101213676204937
# Average Weighted Silhouette Score = 0.1309435441396922 for i = 8
# []
# (array([0, 1], dtype=int64), array([193, 158], dtype=int64))
# ----------------------------------------------------------------------------------------
#
# Score for KMEANS++ = 0.13036971618759763
# Score for KMEANS = 0.10931421961404274
# Score for CMEANS = 0.2182221139845953
# Average Weighted Silhouette Score = 0.12960027637344373 for i = 9
# []
# (array([0, 1], dtype=int64), array([193, 158], dtype=int64))
# ----------------------------------------------------------------------------------------
#
# Score for KMEANS++ = 0.12971664434966262
# Score for KMEANS = 0.10904933905857668
# Score for CMEANS = 0.21267079283508747
# Average Weighted Silhouette Score = 0.05248982077838086 for i = 10
# []
# (array([0, 1], dtype=int64), array([185, 166], dtype=int64))
# ----------------------------------------------------------------------------------------
#
# Score for KMEANS++ = 0.12886449978777714
# Score for KMEANS = 0.1083208603360558
# Score for CMEANS = 0.20945563286171567
# Average Weighted Silhouette Score = 0.055217208176620264 for i = 11
# []
# (array([0, 1], dtype=int64), array([188, 163], dtype=int64))
# ----------------------------------------------------------------------------------------
#
# Score for KMEANS++ = 0.12811722549339116
# Score for KMEANS = 0.10764440011041876
# Score for CMEANS = 0.20632599074771474
# Average Weighted Silhouette Score = 0.056084437384590145 for i = 12
# []
# (array([0, 1], dtype=int64), array([189, 162], dtype=int64))
# ----------------------------------------------------------------------------------------
#
# Score for KMEANS++ = 0.1274933056741831
# Score for KMEANS = 0.10707419341737705
# Score for CMEANS = 0.20178331371424338
# Average Weighted Silhouette Score = 0.12420684429504777 for i = 13
# []
# (array([0, 1], dtype=int64), array([193, 158], dtype=int64))
# ----------------------------------------------------------------------------------------
#
# Score for KMEANS++ = 0.12463774181183468
# Score for KMEANS = 0.10728575998762659
# Score for CMEANS = 0.1996643007927328
# Average Weighted Silhouette Score = 0.06471831369719871 for i = 14
# []
# (array([0, 1], dtype=int64), array([197, 154], dtype=int64))
# ----------------------------------------------------------------------------------------
#
# Score for KMEANS++ = 0.12407072755574182
# Score for KMEANS = 0.1066719034733307
# Score for CMEANS = 0.19461869132432805
# Average Weighted Silhouette Score = 0.12505798792863104 for i = 15
# []
# (array([0, 1], dtype=int64), array([193, 158], dtype=int64))
# ----------------------------------------------------------------------------------------
#
# Score for KMEANS++ = 0.12428986217620505
# Score for KMEANS = 0.10690493954136576
# Score for CMEANS = 0.20008275296835618
# Average Weighted Silhouette Score = 0.12519487030766824 for i = 16
# []
# (array([0, 1], dtype=int64), array([193, 158], dtype=int64))
# ----------------------------------------------------------------------------------------
#
# Score for KMEANS++ = 0.12629573527563642
# Score for KMEANS = 0.10712835654810063
# Score for CMEANS = 0.20850858634897904
# Average Weighted Silhouette Score = 0.1044255145648836 for i = 17
# []
# (array([0, 1], dtype=int64), array([179, 172], dtype=int64))
# ----------------------------------------------------------------------------------------
#
# Score for KMEANS++ = 0.1251466041982815
# Score for KMEANS = 0.11046160465880912
# Score for CMEANS = 0.20641523881935586
# Average Weighted Silhouette Score = 0.1274743570766619 for i = 18
# []
# (array([0, 1], dtype=int64), array([193, 158], dtype=int64))
# ----------------------------------------------------------------------------------------
#
# Score for KMEANS++ = 0.12849172962048613
# Score for KMEANS = 0.11064220880197116
# Score for CMEANS = 0.1901229078299752
# Average Weighted Silhouette Score = 0.07162259180077721 for i = 19
# []
# (array([0, 1], dtype=int64), array([203, 148], dtype=int64))
# ----------------------------------------------------------------------------------------
#
# Score for KMEANS++ = 0.1284796270835196
# Score for KMEANS = 0.11058237083877763
# Score for CMEANS = 0.19322007049658677
# Average Weighted Silhouette Score = 0.0448769357517663 for i = 20
# []
# (array([0, 1], dtype=int64), array([191, 160], dtype=int64))
# ----------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------------------
#
#
#
#
# For K = 3
#
#
#
#
# Score for KMEANS++ = 0.19618546195730613
# Score for KMEANS = 0.102913069582564
# Score for CMEANS = 0.23490682014891245
# Average Weighted Silhouette Score = 0.16733816213169297 for i = 1
# []
# (array([0, 1, 2], dtype=int64), array([146, 110,  95], dtype=int64))
# ----------------------------------------------------------------------------------------
#
# Score for KMEANS++ = 0.18478894566368095
# Score for KMEANS = 0.09360434432595201
# Score for CMEANS = 0.25795035546526596
# Average Weighted Silhouette Score = 0.1661996624234272 for i = 2
# []
# (array([0, 1, 2], dtype=int64), array([129, 121, 101], dtype=int64))
# ----------------------------------------------------------------------------------------
#
# Score for KMEANS++ = 0.19598945362312473
# Score for KMEANS = 0.0895317536343356
# Score for CMEANS = 0.27002553641143723
# Average Weighted Silhouette Score = 0.1970259729973329 for i = 3
# []
# (array([0, 1, 2], dtype=int64), array([ 85, 131, 135], dtype=int64))
# ----------------------------------------------------------------------------------------
#
# Score for KMEANS++ = 0.11772554082820963
# Score for KMEANS = 0.08694851551528543
# Score for CMEANS = 0.2798489287995936
# Average Weighted Silhouette Score = 0.2214807083108282 for i = 4
# []
# (array([0, 1, 2], dtype=int64), array([111,  99, 141], dtype=int64))
# ----------------------------------------------------------------------------------------
#
# Score for KMEANS++ = 0.13172741860319465
# Score for KMEANS = 0.08219349095004513
# Score for CMEANS = 0.28734373896085313
# Average Weighted Silhouette Score = 0.20455513249307608 for i = 5
# []
# (array([0, 1, 2], dtype=int64), array([103, 101, 147], dtype=int64))
# ----------------------------------------------------------------------------------------
#
# Score for KMEANS++ = 0.13705984090539533
# Score for KMEANS = 0.09100084919934735
# Score for CMEANS = 0.2840956423976091
# Average Weighted Silhouette Score = 0.23559256857651034 for i = 6
# []
# (array([0, 1, 2], dtype=int64), array([113, 103, 135], dtype=int64))
# ----------------------------------------------------------------------------------------
#
# Score for KMEANS++ = 0.14643979513917768
# Score for KMEANS = 0.09372141198364624
# Score for CMEANS = 0.284206073946256
# Average Weighted Silhouette Score = 0.1730574881087964 for i = 7
# []
# (array([0, 1, 2], dtype=int64), array([115,  96, 140], dtype=int64))
# ----------------------------------------------------------------------------------------
#
# Score for KMEANS++ = 0.14872983747674431
# Score for KMEANS = 0.09502129327735444
# Score for CMEANS = 0.2814576092016932
# Average Weighted Silhouette Score = 0.2278859017529865 for i = 8
# []
# (array([0, 1, 2], dtype=int64), array([114, 104, 133], dtype=int64))
# ----------------------------------------------------------------------------------------
#
# Score for KMEANS++ = 0.15187573487827663
# Score for KMEANS = 0.09961530700618337
# Score for CMEANS = 0.28811400871291193
# Average Weighted Silhouette Score = 0.2104338284161648 for i = 9
# []
# (array([0, 1, 2], dtype=int64), array([ 86, 104, 161], dtype=int64))
# ----------------------------------------------------------------------------------------
#
# Score for KMEANS++ = 0.22311540561909007
# Score for KMEANS = 0.090051583342379
# Score for CMEANS = 0.299982021384966
# Average Weighted Silhouette Score = 0.20734257063419329 for i = 10
# []
# (array([0, 1, 2], dtype=int64), array([106, 104, 141], dtype=int64))
# ----------------------------------------------------------------------------------------
#
# Score for KMEANS++ = 0.19957204318085606
# Score for KMEANS = 0.07295777030137683
# Score for CMEANS = 0.3069965569615864
# Average Weighted Silhouette Score = 0.070486372893641 for i = 11
# []
# (array([0, 1, 2], dtype=int64), array([125,  56, 170], dtype=int64))
# ----------------------------------------------------------------------------------------
#
# Score for KMEANS++ = 0.20042163395923215
# Score for KMEANS = 0.07364549294329055
# Score for CMEANS = 0.30620895962099276
# Average Weighted Silhouette Score = 0.17796626704180898 for i = 12
# []
# (array([0, 1, 2], dtype=int64), array([145,  71, 135], dtype=int64))
# ----------------------------------------------------------------------------------------
#
# Score for KMEANS++ = 0.20145752305565617
# Score for KMEANS = 0.0742868630196232
# Score for CMEANS = 0.30773022530487354
# Average Weighted Silhouette Score = 0.13326484209161263 for i = 13
# []
# (array([0, 1, 2], dtype=int64), array([139,  66, 146], dtype=int64))
# ----------------------------------------------------------------------------------------
#
# Score for KMEANS++ = 0.23355674542676372
# Score for KMEANS = 0.08850936970548941
# Score for CMEANS = 0.28430198944216767
# Average Weighted Silhouette Score = 0.0630652487986241 for i = 14
# []
# (array([0, 1, 2], dtype=int64), array([ 61, 158, 132], dtype=int64))
# ----------------------------------------------------------------------------------------
#
# Score for KMEANS++ = 0.24345443503147038
# Score for KMEANS = 0.08983684292321802
# Score for CMEANS = 0.28810050329779946
# Average Weighted Silhouette Score = 0.09172005032182744 for i = 15
# []
# (array([0, 1, 2], dtype=int64), array([ 98, 107, 146], dtype=int64))
# ----------------------------------------------------------------------------------------
#
# ...
# Score for KMEANS = 0.06395866229534766
# Score for CMEANS = 0.18909987922366453
# Average Weighted Silhouette Score = 0.09110285983459278 for i = 2
# []
# (array([0, 1, 2], dtype=int64), array([43, 22, 83], dtype=int64))
# ----------------------------------------------------------------------------------------
#
# Score for KMEANS++ = 0.2605326603438547
# Score for KMEANS = 0.090985657038294
# Score for CMEANS = 0.21419945205796892
# Average Weighted Silhouette Score = 0.2605326603438547 for i = 3
# []
# (array([0, 1, 2], dtype=int64), array([ 16,  15, 117], dtype=int64))
# ----------------------------------------------------------------------------------------
#
# Score for KMEANS++ = 0.25264509479431596
# Score for KMEANS = 0.04604007724513406
# Score for CMEANS = 0.2300770399072543
# Average Weighted Silhouette Score = 0.25264509479431596 for i = 4
# []
# (array([0, 1, 2], dtype=int64), array([ 15,  24, 109], dtype=int64))
# ----------------------------------------------------------------------------------------
#
# Score for KMEANS++ = 0.26733583581067416
# Score for KMEANS = 0.057278288224648116
# Score for CMEANS = 0.2600338016986564
# Average Weighted Silhouette Score = 0.10691586871833533 for i = 5
# []
# (array([0, 1, 2], dtype=int64), array([16, 63, 69], dtype=int64))
# ----------------------------------------------------------------------------------------
#
# Score for KMEANS++ = 0.2820778866786591
# Score for KMEANS = 0.07309782347484299
# Score for CMEANS = 0.26211098870065697
# Average Weighted Silhouette Score = 0.2820778866786591 for i = 6
# []
# (array([0, 1, 2], dtype=int64), array([ 18,  20, 110], dtype=int64))
# ----------------------------------------------------------------------------------------
#
# Score for KMEANS++ = 0.3057232898936901
# Score for KMEANS = 0.0852336862440261
# Score for CMEANS = 0.27662586243506704
# Average Weighted Silhouette Score = 0.3082025883358249 for i = 7
# []
# (array([0, 1, 2], dtype=int64), array([32, 21, 95], dtype=int64))
# ----------------------------------------------------------------------------------------
#
# Score for KMEANS++ = 0.18485629927055203
# Score for KMEANS = 0.11703099614084178
# Score for CMEANS = 0.24211207194745754
# Average Weighted Silhouette Score = 0.10648355122927843 for i = 8
# []
# (array([0, 1, 2], dtype=int64), array([61, 48, 39], dtype=int64))
# ----------------------------------------------------------------------------------------
#
# Score for KMEANS++ = 0.1643040027046826
# Score for KMEANS = 0.10185284132240494
# Score for CMEANS = 0.23357115199646108
# Average Weighted Silhouette Score = 0.07382274994941924 for i = 9
# []
# (array([0, 1, 2], dtype=int64), array([56, 55, 37], dtype=int64))
# ----------------------------------------------------------------------------------------
#
# Score for KMEANS++ = 0.15992175811879275
# Score for KMEANS = 0.09867421593515249
# Score for CMEANS = 0.2427708129768397
# Average Weighted Silhouette Score = 0.21606171252179399 for i = 10
# []
# (array([0, 1, 2], dtype=int64), array([71, 40, 37], dtype=int64))
# ----------------------------------------------------------------------------------------
#
# Score for KMEANS++ = 0.07317920746203177
# Score for KMEANS = 0.06513029608175389
# Score for CMEANS = 0.2556077224351428
# Average Weighted Silhouette Score = 0.19165994134107206 for i = 11
# []
# (array([0, 1, 2], dtype=int64), array([41, 37, 70], dtype=int64))
# ----------------------------------------------------------------------------------------
#
# Score for KMEANS++ = 0.12642579653025873
# Score for KMEANS = 0.067122741543982
# Score for CMEANS = 0.2603409074652321
# Average Weighted Silhouette Score = 0.19383475041466663 for i = 12
# []
# (array([0, 1, 2], dtype=int64), array([92, 36, 20], dtype=int64))
# ----------------------------------------------------------------------------------------
#
# Score for KMEANS++ = 0.07367251117843256
# Score for KMEANS = 0.05855007621747437
# Score for CMEANS = 0.28224761501389284
# Average Weighted Silhouette Score = 0.22708902066031988 for i = 13
# []
# (array([0, 1, 2], dtype=int64), array([74, 45, 29], dtype=int64))
# ----------------------------------------------------------------------------------------
#
# Score for KMEANS++ = 0.13251884443021014
# Score for KMEANS = 0.10303287785149358
# Score for CMEANS = 0.2831123204629101
# Average Weighted Silhouette Score = 0.20695981973037894 for i = 14
# []
# (array([0, 1, 2], dtype=int64), array([33, 78, 37], dtype=int64))
# ----------------------------------------------------------------------------------------
#
# Score for KMEANS++ = 0.09303041114326527
# Score for KMEANS = 0.10413384639448489
# Score for CMEANS = 0.21385325260240837
# Average Weighted Silhouette Score = 0.12507467946131925 for i = 15
# []
# (array([0, 1, 2], dtype=int64), array([52, 55, 41], dtype=int64))
# ----------------------------------------------------------------------------------------
#
# Score for KMEANS++ = 0.07359955349829896
# Score for KMEANS = 0.08899674500091127
# Score for CMEANS = 0.25356411377462706
# Average Weighted Silhouette Score = 0.17064380324887082 for i = 16
# []
# (array([0, 1, 2], dtype=int64), array([68, 53, 27], dtype=int64))
# ----------------------------------------------------------------------------------------
#
# Score for KMEANS++ = 0.09013802396175899
# Score for KMEANS = 0.07980121010506176
# Score for CMEANS = 0.24874846049330984
# Average Weighted Silhouette Score = 0.22186639196565966 for i = 17
# []
# (array([0, 1, 2], dtype=int64), array([88, 22, 38], dtype=int64))
# ----------------------------------------------------------------------------------------
#
# Score for KMEANS++ = 0.2865487773814964
# Score for KMEANS = 0.0868031114337919
# Score for CMEANS = 0.32882712760477145
# Average Weighted Silhouette Score = 0.24808904670705387 for i = 18
# []
# (array([0, 1, 2], dtype=int64), array([116,  24,   8], dtype=int64))
# ----------------------------------------------------------------------------------------
#
# Score for KMEANS++ = 0.11410409118342109
# Score for KMEANS = 0.04951573929863952
# Score for CMEANS = 0.3806699299657899
# Average Weighted Silhouette Score = 0.4088734924433623 for i = 19
# []
# (array([0, 1, 2], dtype=int64), array([115,   1,  32], dtype=int64))
# ----------------------------------------------------------------------------------------
#
# Score for KMEANS++ = 0.3909191517626968
# Score for KMEANS = 0.10207802963488571
# Score for CMEANS = 0.37892538485637783
# Average Weighted Silhouette Score = 0.3703450168836206 for i = 20
# []
# (array([0, 1, 2], dtype=int64), array([ 41,   1, 106], dtype=int64))
# ----------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------------------
#
#
#
#
# For K = 4
#
#
#
#
# Score for KMEANS++ = 0.18883511913546142
# Score for KMEANS = 0.16304408449092495
# Score for CMEANS = 0.17585362761171197
# Average Weighted Silhouette Score = 0.0366733888796668 for i = 1
# [134]
# (array([0, 1, 2, 3], dtype=int64), array([61, 24, 60,  2], dtype=int64))
# ----------------------------------------------------------------------------------------
#
# Score for KMEANS++ = 0.02707291959535165
# Score for KMEANS = 0.13124664054359927
# Score for CMEANS = 0.3282292193753443
# Average Weighted Silhouette Score = 0.27115345132067764 for i = 2
# []
# (array([0, 1, 2, 3], dtype=int64), array([29,  1, 79, 38], dtype=int64))
# ----------------------------------------------------------------------------------------
#
# Score for KMEANS++ = 0.05720812923145029
# Score for KMEANS = 0.013982759864690003
# Score for CMEANS = 0.254819730213444
# Average Weighted Silhouette Score = 0.24680971500927315 for i = 3
# []
# (array([0, 1, 2, 3], dtype=int64), array([22, 57,  1, 67], dtype=int64))
# ----------------------------------------------------------------------------------------
#
# Score for KMEANS++ = 0.12738922700417585
# Score for KMEANS = 0.054442368844199944
# Score for CMEANS = 0.23184814699304873
# Average Weighted Silhouette Score = 0.27807753833398424 for i = 4
# [ 20  40  52 132]
# (array([0, 1, 2, 3], dtype=int64), array([ 5, 29, 84, 25], dtype=int64))
# ----------------------------------------------------------------------------------------
#
# Score for KMEANS++ = 0.04994503240262947
# Score for KMEANS = 0.07925387415584481
# Score for CMEANS = 0.27799410148391884
# Average Weighted Silhouette Score = 0.2787530030589718 for i = 5
# []
# (array([0, 1, 2, 3], dtype=int64), array([83,  1, 49, 10], dtype=int64))
# ----------------------------------------------------------------------------------------
#
# Score for KMEANS++ = 0.012794995315416117
# Score for KMEANS = 0.17401524785749822
# Score for CMEANS = 0.3154798359526924
# Average Weighted Silhouette Score = 0.30036552308910314 for i = 6
# []
# (array([0, 1, 2, 3], dtype=int64), array([11, 45, 86,  1], dtype=int64))
# ----------------------------------------------------------------------------------------
#
# Score for KMEANS++ = 0.04571286767612149
# Score for KMEANS = 0.025429927824847987
# Score for CMEANS = 0.28468902177251826
# Average Weighted Silhouette Score = 0.2800825448512049 for i = 7
# []
# (array([0, 1, 2, 3], dtype=int64), array([16, 81,  1, 45], dtype=int64))
# ----------------------------------------------------------------------------------------
#
# Score for KMEANS++ = 0.23549538323219243
# Score for KMEANS = 0.0662610021871083
# Score for CMEANS = 0.3310079857780391
# Average Weighted Silhouette Score = 0.040925834821667 for i = 8
# []
# (array([0, 1, 2, 3], dtype=int64), array([92,  9, 39,  3], dtype=int64))
# ----------------------------------------------------------------------------------------
#
# Score for KMEANS++ = 0.10158274777968147
# Score for KMEANS = 0.04394319511860861
# Score for CMEANS = 0.3337738542653114
# Average Weighted Silhouette Score = 0.32764770102398955 for i = 9
# []
# (array([0, 1, 2, 3], dtype=int64), array([ 2, 78, 50, 13], dtype=int64))
# ----------------------------------------------------------------------------------------
#
# Score for KMEANS++ = 0.07464643286572423
# Score for KMEANS = 0.08370866663742017
# Score for CMEANS = 0.3337661707056125
# Average Weighted Silhouette Score = 0.3102821881120325 for i = 10
# []
# (array([0, 1, 2, 3], dtype=int64), array([38,  2, 22, 81], dtype=int64))
# ----------------------------------------------------------------------------------------
#
# Score for KMEANS++ = 0.138274004530726
# Score for KMEANS = 0.0815087396033547
# Score for CMEANS = 0.3207013787523137
# Average Weighted Silhouette Score = 0.2658757527210528 for i = 11
# []
# (array([0, 1, 2, 3], dtype=int64), array([51,  3, 21, 68], dtype=int64))
# ----------------------------------------------------------------------------------------
#
# Score for KMEANS++ = 0.11309578545531593
# Score for KMEANS = 0.09689444999857948
# Score for CMEANS = 0.46323372302175464
# Average Weighted Silhouette Score = 0.4674361640098991 for i = 12
# []
# (array([0, 1, 2, 3], dtype=int64), array([ 3, 10, 37, 93], dtype=int64))
# ----------------------------------------------------------------------------------------
#
# Score for KMEANS++ = 0.09562770801581397
# Score for KMEANS = 0.11515664324181568
# Score for CMEANS = 0.4845533341420508
# Average Weighted Silhouette Score = 0.4863840473007115 for i = 13
# []
# (array([0, 1, 2, 3], dtype=int64), array([104,  33,   4,   2], dtype=int64))
# ----------------------------------------------------------------------------------------
#
# Score for KMEANS++ = 0.09901073013423803
# Score for KMEANS = 0.0904802227550854
# Score for CMEANS = 0.3629485317819746
# Average Weighted Silhouette Score = 0.36863581506665377 for i = 14
# []
# (array([0, 1, 2, 3], dtype=int64), array([ 4, 13, 38, 88], dtype=int64))
# ----------------------------------------------------------------------------------------
#
# Score for KMEANS++ = 0.11597493225452114
# Score for KMEANS = 0.04084841849193938
# Score for CMEANS = 0.3110932754079776
# Average Weighted Silhouette Score = 0.3089588069927486 for i = 15
# []
# (array([0, 1, 2, 3], dtype=int64), array([13, 69, 56,  5], dtype=int64))
# ----------------------------------------------------------------------------------------
#
# Score for KMEANS++ = 0.1038949758103349
# Score for KMEANS = 0.005531664221274817
# Score for CMEANS = 0.5054749765903712
# Average Weighted Silhouette Score = 0.4894149067867937 for i = 16
# []
# (array([0, 1, 2, 3], dtype=int64), array([  4, 105,  31,   3], dtype=int64))
# ----------------------------------------------------------------------------------------
#
# Score for KMEANS++ = 0.09463575633979586
# Score for KMEANS = 0.035171862329474356
# Score for CMEANS = 0.3455906105399345
# Average Weighted Silhouette Score = 0.32166489556159245 for i = 17
# []
# (array([0, 1, 2, 3], dtype=int64), array([ 4, 15, 57, 67], dtype=int64))
# ----------------------------------------------------------------------------------------
#
# Score for KMEANS++ = 0.13117916963389864
# Score for KMEANS = 0.04510070095612697
# Score for CMEANS = 0.44408862750231476
# Average Weighted Silhouette Score = 0.43828112493387095 for i = 18
# []
# (array([0, 1, 2, 3], dtype=int64), array([ 5, 98, 14, 26], dtype=int64))
# ----------------------------------------------------------------------------------------
#
# Score for KMEANS++ = 0.16578915502071456
# Score for KMEANS = 0.023669219841311543
# Score for CMEANS = 0.2646517082669572
# Average Weighted Silhouette Score = 0.25336826394618456 for i = 19
# []
# (array([0, 1, 2, 3], dtype=int64), array([16,  5, 55, 67], dtype=int64))
# ----------------------------------------------------------------------------------------
#
# Score for KMEANS++ = 0.23605407578980742
# Score for KMEANS = 0.0037240344221327183
# Score for CMEANS = 0.5256795594173359
# Average Weighted Silhouette Score = 0.5256795594173359 for i = 20
# []
# (array([0, 1, 2, 3], dtype=int64), array([  4, 108,  28,   3], dtype=int64))
# ----------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------------------
#
#
#
#
# For K = 5
#
#
#
#
# Score for KMEANS++ = 0.26632732098313094
# Score for KMEANS = 0.014892076825823912
# Score for CMEANS = 0.3431742700289834
# Average Weighted Silhouette Score = 0.3386015287596276 for i = 1
# []
# (array([0, 1, 2, 3, 4], dtype=int64), array([ 4, 67,  4, 62,  6], dtype=int64))
# ----------------------------------------------------------------------------------------
#
# Score for KMEANS++ = 0.04621234514082445
# Score for KMEANS = 0.15907010024395105
# Score for CMEANS = 0.38609363458758283
# Average Weighted Silhouette Score = 0.3658766765546515 for i = 2
# []
# (array([0, 1, 2, 3, 4], dtype=int64), array([14,  4, 54,  2, 69], dtype=int64))
# ----------------------------------------------------------------------------------------
#
# Score for KMEANS++ = 0.03221070244623953
# Score for KMEANS = 0.16547394784329997
# Score for CMEANS = 0.41398334586942226
# Average Weighted Silhouette Score = 0.39066622932365364 for i = 3
# []
# (array([0, 1, 2, 3, 4], dtype=int64), array([38,  4, 85, 12,  4], dtype=int64))
# ----------------------------------------------------------------------------------------
#
# Score for KMEANS++ = 0.12471043395936268
# Score for KMEANS = 0.39244650613354654
# Score for CMEANS = 0.5233605518004733
# Average Weighted Silhouette Score = 0.5052241069751597 for i = 4
# []
# (array([0, 1, 2, 3, 4], dtype=int64), array([ 1, 99, 34,  5,  4], dtype=int64))
# ----------------------------------------------------------------------------------------
#
# Score for KMEANS++ = 0.8045623516556734
# Score for KMEANS = 0.3823727336032905
# Score for CMEANS = 0.37347232390876284
# Average Weighted Silhouette Score = 0.1957793495314025 for i = 5
# []
# (array([0, 1, 2, 4], dtype=int64), array([86,  5,  6, 46], dtype=int64))
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-35-e074ab7dbf60> in <module>
#     100                     y=0
#     101                     for j1 in range(len(columns)):
# --> 102                         x+=np.sqrt(np.abs((df[columns[j1]] - centroids[i1][j1]) ** 2))
#     103                     y=np.exp(-1*x)
#     104                     # sqrt((x1 - x2)^2 - (y1 - y2)^2)
#
# IndexError: list index out of range

# %%
np.unique(labels,return_counts=True)[1].argmin()==1
# Out:
# True
